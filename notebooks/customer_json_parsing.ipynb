# %% [markdown]
# Listing the files meta data using file system magic commands

# %%
# %fs ls /Volumes/gizmobox/landing/operational_data/

# %% [markdown]
# Listing the file paths using databricks utils object

# %%
display(dbutils.fs.ls('/Volumes/gizmobox/landing/operational_data/customers/'))

# %% [markdown]
# Reading a single customer json file using sql.

# %%
# %sql
select * from json.`/Volumes/gizmobox/landing/operational_data/customers/customers_2024_10.json`

# %% [markdown]
# Reading multiple json customer file which starts with **customer_2024_**

# %%
# %sql
select * from json.`/Volumes/gizmobox/landing/operational_data/customers/customers_2024_*.json`

# %% [markdown]
# Reading multiple json customer file from the customers directory in the volume.

# %%
# %sql
select * from json.`/Volumes/gizmobox/landing/operational_data/customers/`
