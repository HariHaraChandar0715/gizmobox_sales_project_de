# %%
## Displaying the databricks file utilities

df_ls = dbutils.fs.ls('dbfs:/Volumes/gizmobox/landing/operational_data/')

# %%
file_counter = 0
folder_counter = 0

for info in df_ls:
    if info.name.endswith('/'):
        folder_counter+=1
    else:
        file_counter+=1

print(f'Folder Counts : {folder_counter}')
print(f'File counts : {file_counter}')

# %%
dbutils.help()
